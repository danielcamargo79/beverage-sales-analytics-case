# %% [markdown]
# # 00 - Discovery
#
# ## Objetivo
#
# Este notebook tem como objetivo validar a estrutura inicial do projeto, confirmar a criação das camadas da arquitetura Medallion e localizar os arquivos CSV carregados na camada Landing.
#
# ## Arquitetura
#
# CSV
# → Landing
# → Bronze
# → Silver
# → Gold
# → Analytics
#
# ## Arquivos esperados
#
# - abi_bus_case1_beverage_sales_20210726.csv
# - abi_bus_case1_beverage_channel_group_20210726.csv
#
# ## Resultado esperado
#
# Os arquivos devem estar disponíveis no volume:
#
# /Volumes/workspace/landing/raw_files

# %%
print("Beverage Sales Case - Discovery")
# Out:
# Beverage Sales Case - Discovery

# %%
display(dbutils.fs.ls("/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/</td><td>Volumes/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/Workspace/</td><td>Workspace/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
display(dbutils.fs.ls("dbfs:/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/</td><td>Volumes/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/Workspace/</td><td>Workspace/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
display(dbutils.fs.ls("dbfs:/Workspace"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Workspace/.rm-rf-guard</td><td>.rm-rf-guard</td><td>0</td><td>1780792588650</td></tr><tr><td>dbfs:/Workspace/Repos/</td><td>Repos/</td><td>4096</td><td>1780793023137</td></tr><tr><td>dbfs:/Workspace/Shared/</td><td>Shared/</td><td>4096</td><td>1780793023137</td></tr><tr><td>dbfs:/Workspace/Users/</td><td>Users/</td><td>4096</td><td>1780793023137</td></tr></tbody></table></div>

# %%
spark.sql("SHOW VOLUMES IN workspace.default").show(truncate=False)
# Out:
# +--------+-----------+
# |database|volume_name|
# +--------+-----------+
# +--------+-----------+

# %%
# Lista os arquivos armazenados na Landing Layer
display(
    dbutils.fs.ls(
        "/Volumes/workspace/landing/raw_files"
    )
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/workspace/landing/raw_files/abi_bus_case1_beverage_channel_group_20210726.csv</td><td>abi_bus_case1_beverage_channel_group_20210726.csv</td><td>1198</td><td>1780793412000</td></tr><tr><td>dbfs:/Volumes/workspace/landing/raw_files/abi_bus_case1_beverage_sales_20210726.csv</td><td>abi_bus_case1_beverage_sales_20210726.csv</td><td>3412196</td><td>1780793429000</td></tr></tbody></table></div>
